# %%
import nltk
import pandas as pd
import io
import re
from string import punctuation
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from random import shuffle
#nltk.download('punkt')
#nltk.download('stopwords')
#nltk.download('PorterStemmer')

# %%
data = pd.read_csv('cleanerstill.csv', sep=";")
data.head()
# Out:
# C:\Users\xetrev\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   age       body type               diet    drinks      drugs  \
# 0  22  a little extra  strictly anything  socially      never
# 1  35         average       mostly other     often  sometimes
# 2  38            thin           anything  socially
# 3  23            thin         vegetarian  socially
# 4  29        athletic                     socially      never
#
#                            education  \
# 0      working on college university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college university
# 4  graduated from college university
#
#                                               essay0  \
# 0  about me   i would love to think that i was so...
# 1  i am a chef  this is what that means  1  i am ...
# 2  i'm not ashamed of much  but writing public te...
# 3          i work in a library and go to school
# 4  hey how's it going currently vague on the prof...
#
#                                               essay4  \
# 0  books  absurdistan  the republic  of mice and ...
# 1  i am die hard christopher moore fan  i don't r...
# 2  okay this is where the cultural matrix gets so...
# 3  bataille  celine  beckett      lynch  jarmusch...
# 4  music  bands  rappers  musicians at the moment...
#
#                         essay6  \
# 0  duality and humorous things
# 1
# 2
# 3   cats and german philosophy
# 4
#
#                                               essay7  ...  \
# 0  trying to find someone to hang out with  i am ...  ...
# 1                                                     ...
# 2  viewing  listening  dancing  talking  drinking...  ...
# 3                                                     ...
# 4                                                     ...
#
#                           location                              offspring  \
# 0  south san francisco  california  doesnt have kids  but might want them
# 1              oakland  california  doesnt have kids  but might want them
# 2        san francisco  california
# 3             berkeley  california                       doesnt want kids
# 4        san francisco  california
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex                         sign  \
# 0     agnosticism and very serious about it   m                       gemini
# 1  agnosticism but not too serious about it   m                       cancer
# 2                                             m  pisces but it doesnt matter
# 3                                             m                       pisces
# 4                                             m                     aquarius
#
#       smokes                                             speaks     status
# 0  sometimes                                            english     single
# 1         no  english  fluently   spanish  poorly   french  ...     single
# 2         no                               english  french  c    available
# 3         no                           english  german  poorly      single
# 4         no                                            english     single
#
# [5 rows x 26 columns]

# %%
data.drop('drinks', axis=1)

mask = (data['ethnicity'] != ' ') & (type(data['ethnicity']) != float) & (data['age'] != ' ') & (data['sex'] != ' ')
# mask removes all rows where ethnicity, age and sex is not given. Also removes rows where ethnicity is NaN. This particular value is not present for age and sex, hence it is not masked out.
data_new = data[mask]

data_new
# Out:
#       age       body type               diet      drinks      drugs  \
# 0      22  a little extra  strictly anything    socially      never
# 1      35         average       mostly other       often  sometimes
# 3      23            thin         vegetarian    socially
# 4      29        athletic                       socially      never
# 5      29         average    mostly anything    socially
# ...    ..             ...                ...         ...        ...
# 59939  31                                       socially      never
# 59941  24             fit    mostly anything       often  sometimes
# 59942  42         average    mostly anything  not at all      never
# 59943  27        athletic    mostly anything    socially      often
# 59944  39         average                       socially
#
#                                education  \
# 0          working on college university
# 1                  working on space camp
# 3          working on college university
# 4      graduated from college university
# 5      graduated from college university
# ...                                  ...
# 59939         working on masters program
# 59941      working on college university
# 59942     graduated from masters program
# 59943      working on college university
# 59944     graduated from masters program
#
#                                                   essay0  \
# 0      about me   i would love to think that i was so...
# 1      i am a chef  this is what that means  1  i am ...
# 3              i work in a library and go to school
# 4      hey how's it going currently vague on the prof...
# 5      i'm an australian living in san francisco  but...
# ...                                                  ...
# 59939  real deal  i am sensitive  sorry  tears includ...
# 59941  i'm nick  i never know what to write about mys...
# 59942  hello i enjoy traveling  watching movies  and ...
# 59943   all i have in this world are my balls and my ...
# 59944  is it odd that having a little  enemy  status ...
#
#                                                   essay4  \
# 0      books  absurdistan  the republic  of mice and ...
# 1      i am die hard christopher moore fan  i don't r...
# 3      bataille  celine  beckett      lynch  jarmusch...
# 4      music  bands  rappers  musicians at the moment...
# 5      books  to kill a mockingbird  lord of the ring...
# ...                                                  ...
# 59939  too many to name      a new earth  kite runner...
# 59941  movies  hook  the greatest adventure ever   gl...
# 59942  last book   game change   movies  bourne serie...
# 59943  where to begin musically  right now i listen t...
# 59944  i just read the help by kathryn stockett  sooo...
#
#                                                   essay6  \
# 0                            duality and humorous things
# 1
# 3                             cats and german philosophy
# 4
# 5      what my contribution to the world is going to ...
# ...                                                  ...
# 59939  how i am gonna answer this question    existen...
# 59941  i do most of my thinking on the bus to from wo...
# 59942           aside from work  how to improve my home
# 59943          what can i do to make someone chuckle
# 59944  sex  myself  other people  how amazing everyth...
#
#                                                   essay7  ...  \
# 0      trying to find someone to hang out with  i am ...  ...
# 1                                                         ...
# 3                                                         ...
# 4                                                         ...
# 5                                    out with my friends  ...
# ...                                                  ...  ...
# 59939  doing the obvious two things everyone is doing...  ...
# 59941       bringin' home bacon  or drinking and shakin'  ...
# 59942    out enjoying friendly conversation over dinner   ...
# 59943  what i would do on any other day  everydays a ...  ...
# 59944  out at happy hour with my friends  running int...  ...
#
#                               location                              offspring  \
# 0      south san francisco  california  doesnt have kids  but might want them
# 1                  oakland  california  doesnt have kids  but might want them
# 3                 berkeley  california                       doesnt want kids
# 4            san francisco  california
# 5            san francisco  california  doesnt have kids  but might want them
# ...                                ...                                    ...
# 59939        san francisco  california
# 59941        san francisco  california                       doesnt have kids
# 59942  south san francisco  california                       doesnt have kids
# 59943        san francisco  california       doesnt have kids  but wants them
# 59944        san francisco  california
#
#       orientation                       pets  \
# 0        straight  likes dogs and likes cats
# 1        straight  likes dogs and likes cats
# 3        straight                 likes cats
# 4        straight  likes dogs and likes cats
# 5        straight                 likes cats
# ...           ...                        ...
# 59939    straight                 likes dogs
# 59941    straight  likes dogs and likes cats
# 59942    straight
# 59943    straight  likes dogs and likes cats
# 59944         gay  likes dogs and likes cats
#
#                                         religion sex  \
# 0          agnosticism and very serious about it   m
# 1       agnosticism but not too serious about it   m
# 3                                                  m
# 4                                                  m
# 5                                        atheism   m
# ...                                          ...  ..
# 59939                                agnosticism   f
# 59941                                agnosticism   m
# 59942  christianity but not too serious about it   m
# 59943   agnosticism but not too serious about it   m
# 59944          catholicism and laughing about it   m
#
#                                     sign          smokes  \
# 0                                 gemini       sometimes
# 1                                 cancer              no
# 3                                 pisces              no
# 4                               aquarius              no
# 5                                 taurus              no
# ...                                  ...             ...
# 59939                        sagittarius              no
# 59941           leo but it doesnt matter              no
# 59942   sagittarius but it doesnt matter              no
# 59943     leo and its fun to think about  trying to quit
# 59944  gemini and its fun to think about       sometimes
#
#                                                   speaks  status
# 0                                                english  single
# 1      english  fluently   spanish  poorly   french  ...  single
# 3                               english  german  poorly   single
# 4                                                english  single
# 5                     english  fluently   chinese  okay   single
# ...                                                  ...     ...
# 59939                  english  fluently   french  farsi  single
# 59941                                 english  fluently   single
# 59942                                 english  fluently   single
# 59943  english  fluently   spanish  poorly   chinese ...  single
# 59944                                            english  single
#
# [54265 rows x 26 columns]
